# %% [markdown]
# <a href="https://colab.research.google.com/github/murilosenai/Estudo-de-Python/blob/master/exercicio2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Faça um menu com 5 opções: 1-adicionar contato (nome e telefone), 2-buscar contato (por
# nome ou telefone), 3-remover contato (por nome), 4-listar agenda e 5-sair do programa. Utilize
# funções para implementar as opções e armazene as informações em listas e dicionários.

# observação usei dicionario somente na opção 2 buscar por telefone, somente porque esta no exercicio senão nem iria usar.


import os

agenda = []
def pede_nome():
     return(input("Nome: "))

def pede_telefone():
     return(input("Telefone: "))

def mostra_dados(nome, telefone):
     print("Nome: %s Telefone: %s" % (nome, telefone))

def pesquisa(nome):
     mnome = nome.lower()
     for p, e in enumerate(agenda):
         if e[0].lower() == mnome:
               return p
     return None

def novo():
     global agenda
     nome = pede_nome()
     telefone = pede_telefone()
     agenda.append([nome, telefone])

def apaga():
     global agenda
     nome = pede_nome()
     p = pesquisa(nome)
     if p != None:
         del agenda[p]
     else:
         print("Nome não encontrado.")

def listarAgenda():    
     for e in agenda:
         mostra_dados(e[0], e[1])

def encontrar(elemento):
    pos_i = 0
    pos_j = 0
      

def buscar():
     global agenda
     escolha = int(input("Escolha [1] ou [2] para telefone"))
     
     
     if escolha == 1:
       nome = pede_nome()
       p = pesquisa(nome)
       if p != None:
         agenda[p]
         print("Valor encontrado")
       else:
         print("Nome não encontrado.")
     
    
     if escolha == 2:
       contatos = dict(agenda) 
       print("--------------------------")     
       resultado = pede_telefone() in contatos.values()
       if resultado == True:
         print ("Valor encontrado")
         print("--------------------------")
       else:
         print("Valor não encontrado")
         print("--------------------------")

os.system('cls' if os.name == 'nt' else 'clear')
def valida_faixa_inteiro(pergunta, inicio, fim):
     while True:
         try:
               valor = int(input(pergunta))
               if inicio <= valor <= fim:
                   return(valor)
         except ValueError:
               print("Valor inválido, favor digitar entre %d e %d" % (inicio, fim))

os.system('cls' if os.name == 'nt' else 'clear')
def menu():
     print("""
   1 - Adicionar 5 
   2 - Buscar contato (por nome ou telefone)
   3 - Remover contato (por nome)
   4 - Listar Agenda
   5 - Sair
   
""")
     return valida_faixa_inteiro("Escolha uma opção: ",0,5)

while True:
     opção = menu()
     if opção == 5:
         break
     elif opção == 1:
         novo()
     elif opção == 2:
         buscar()
     elif opção == 3:
         apaga()
     elif opção == 4:
         listarAgenda()


print()
print()
print()
os.system("pause")
# Out:
#    1 - Adicionar 5
#    2 - Buscar contato (por nome ou telefone)
#    3 - Remover contato (por nome)
#    4 - Listar Agenda
#    5 - Sair
